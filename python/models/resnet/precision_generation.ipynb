# %%
# only run this cell on colab

from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# %cd /content/gdrive/MyDrive/model_generation
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive/model_generation

# %%
def reload_modules():
    import importlib
    import models
    importlib.reload(models)
    import models

# %%
reload_modules()

# %%
import models

# %%
# make the regular python models w/ different overall precision

# %%
model = models.make_untrained_resnet_model(50, torch.float32)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
def GET_CLASS_VARIABLES(obj):
    if obj is None:
        raise ValueError("object cannot be None")
    return [(attr, type(getattr(obj, attr)).__name__) for attr in dir(obj)
            if not callable(getattr(obj, attr)) and not (attr.startswith('_') or attr.endswith('_'))]


GET_CLASS_VARIABLES(model)
# Out:
# [('T_destination', 'TypeVar'),
#  ('base_width', 'int'),
#  ('call_super_init', 'bool'),
#  ('dilation', 'int'),
#  ('dump_patches', 'bool'),
#  ('groups', 'int'),
#  ('inplanes', 'int'),
#  ('training', 'bool')]

# %%
import torch

dtype = torch.float64
model = models.make_untrained_resnet_model(50, dtype)
# train model
models.train_resnet_model(model, 50, None, 0, 1, None, dtype)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fc9fd5748af3> in <cell line: 6>()
#       4 model = models.make_untrained_resnet_model(50, dtype)
#       5 # train model
# ----> 6 models.train_resnet_model(model, 50, None, 0, 1, None, dtype)
#
# ...

# %%
models.save_resnet_model(model, 50, dtype, "torchscript")

# %%
import torch
for block_size in [18, 34, 50]:
    for dtype in [torch.float64]:
        model = models.make_untrained_resnet_model(block_size, dtype)
        models.train_resnet_model(model, block_size, None, 0, 20, None, dtype)
        models.save_resnet_model(model, block_size, dtype, "weights")
        models.save_resnet_model(model, block_size, dtype, "torchscript")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# epoch=0
# Epoch 1/20 - Loss: 1.967, Accuracy: 40.23%
# Saved new best model with accuracy: 40.23%
# epoch=1
# Epoch 2/20 - Loss: 1.375, Accuracy: 54.35%
# Saved new best model with accuracy: 54.35%
# epoch=2
# Epoch 3/20 - Loss: 1.002, Accuracy: 66.26%
# Saved new best model with accuracy: 66.26%
# epoch=3
# Epoch 4/20 - Loss: 0.785, Accuracy: 65.19%
# epoch=4
# Epoch 5/20 - Loss: 0.689, Accuracy: 70.73%
# Saved new best model with accuracy: 70.73%
# epoch=5
# Epoch 6/20 - Loss: 0.638, Accuracy: 74.07%
# Saved new best model with accuracy: 74.07%
# epoch=6
# Epoch 7/20 - Loss: 0.584, Accuracy: 68.68%
# epoch=7
# Epoch 8/20 - Loss: 0.542, Accuracy: 70.42%
# epoch=8
# Epoch 9/20 - Loss: 0.507, Accuracy: 73.57%
# epoch=9
# Epoch 10/20 - Loss: 0.466, Accuracy: 78.28%
# Saved new best model with accuracy: 78.28%
# epoch=10
# Epoch 11/20 - Loss: 0.433, Accuracy: 83.42%
# ...

# %%
test_load_model = models.load_resnet_model(50, torch.float64, "weights", None, None, "./saved_models")

# %%
# make the regular python modules, but now exported using torchscript

# %%
# make the mixed precision python modules
